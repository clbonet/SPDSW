# %%
import pandas as pd
import numpy as np

# %%
results_session = pd.read_csv("./da_particles_cross_session.csv")

# %% [markdown]
# ### Cross Session

# %%
results_session
# Out:
#      Unnamed: 0     align  no_align       time distance  n_proj  n_epochs  \
# 0             0  0.832740  0.822064  14.002963      les     500       500
# 1             1  0.832740  0.822064  14.002963      les     500       500
# 2             2  0.832740  0.822064  14.002963      les     500       500
# 3             3  0.832740  0.822064  14.002963      les     500       500
# 4             4  0.832740  0.822064  14.002963      les     500       500
# ..          ...       ...       ...        ...      ...     ...       ...
# 495         495  0.806818  0.757576   3.511983    logsw     500       500
# 496         496  0.806818  0.757576   3.511983    logsw     500       500
# 497         497  0.806818  0.757576   3.511983    logsw     500       500
# 498         498  0.806818  0.757576   3.511983    logsw     500       500
# 499         499  0.806818  0.757576   3.511983    logsw     500       500
#
#      seed  subject  target_subject  multifreq   reg  cross_subject
# 0    2473        1               0      False  10.0          False
# 1    2473        1               0      False  10.0          False
# 2    2473        1               0      False  10.0          False
# 3    2473        1               0      False  10.0          False
# 4    2473        1               0      False  10.0          False
# ..    ...      ...             ...        ...   ...            ...
# 495   929        9               0      False   1.0          False
# 496   929        9               0      False   1.0          False
# 497   929        9               0      False   1.0          False
# 498   929        9               0      False   1.0          False
# 499   929        9               0      False   1.0          False
#
# [500 rows x 13 columns]

# %%
distances = results_session["distance"].unique()
subjects = results_session["subject"].unique()

# %%
n_epochs = 500

L_session = {}
for distance in distances:
    L_session[distance] = {}
L_session["no_align"] = {}


for distance in distances:
    for s in subjects:
        dico_distances = {"mean_score": 0, "std_score": 0, "mean_time": 0, "std_time":0}

        scores = results_session[
            (results_session["distance"] == distance)
            & (results_session["subject"] == s)
            & (results_session["n_epochs"] == n_epochs)
        ]["align"]
        m_score = scores.mean()
        std_score = scores.std()
        
        times = results_session[
            (results_session["distance"] == distance)
            & (results_session["subject"] == s)
            & (results_session["n_epochs"] == n_epochs)
        ]["time"]
        m_t = times.mean()
        std_t = times.std()
        
        dico_distances["mean_score"] = m_score
        dico_distances["std_score"] = std_score
        dico_distances["mean_time"] = m_t
        dico_distances["std_time"] = std_t
        
        L_session[distance][s] = dico_distances
        
        
for s in subjects:
    dico_distances = {"mean_score": 0, "std_score": 0, "mean_time": 0, "std_time":0}

    scores = results_session[
        (results_session["distance"] == distance)
        & (results_session["subject"] == s)
        & (results_session["n_epochs"] == n_epochs)
    ]["no_align"]
    m_score = scores.mean()
    std_score = scores.std()

    dico_distances["mean_score"] = m_score
    dico_distances["std_score"] = std_score

    L_session["no_align"][s] = dico_distances

# %%
acc_session = np.zeros((len(subjects), len(distances)+1))
acc_std_session = np.zeros((len(subjects), len(distances)))
t_session = np.zeros((len(subjects), len(distances)))
t_std_session = np.zeros((len(subjects), len(distances)))

for i, distance in enumerate(distances):
    for j, s in enumerate(subjects):
        acc_session[j, i] = L_session[distance][s]["mean_score"]
        acc_std_session[j, i] = L_session[distance][s]["std_score"]
        t_session[j, i] = L_session[distance][s]["mean_time"]
        t_std_session[j, i] = L_session[distance][s]["std_time"]
        
distance = "no_align"        
for j, s in enumerate(subjects):
    acc_session[j, -1] = L_session[distance][s]["mean_score"]

# %%
print("Accuracy Cross Session + Particles")
pd.DataFrame(acc_session, index=subjects, columns=np.concatenate([distances, ["no_align"]]))
# Out:
# Accuracy Cross Session + Particles
#         les       lew     spdsw     logsw  no_align
# 1  0.829181  0.779359  0.851957  0.851957  0.822064
# 3  0.814652  0.824176  0.871062  0.863736  0.798535
# 7  0.732852  0.790614  0.818051  0.817329  0.722022
# 8  0.850185  0.800738  0.841328  0.833210  0.793358
# 9  0.704545  0.761364  0.803030  0.790152  0.757576

# %%
pd.DataFrame(acc_session, index=subjects, columns=np.concatenate([distances, ["no_align"]])).mean(axis=0)
# Out:
# les         0.786283
# lew         0.791250
# spdsw       0.837086
# logsw       0.831277
# no_align    0.778711
# dtype: float64

# %%
pd.DataFrame(acc_session, index=subjects, columns=np.concatenate([distances, ["no_align"]])).std(axis=0)
# Out:
# les         0.063766
# lew         0.023501
# spdsw       0.026999
# logsw       0.029030
# no_align    0.039203
# dtype: float64

# %%
print("Runtime Cross Session + Particles")
pd.DataFrame(t_session, index=subjects, columns=distances)
# Out:
# Runtime Cross Session + Particles
#          les       lew     spdsw     logsw
# 1  10.953869  8.811712  3.747367  3.757061
# 3  10.448567  8.472196  3.728346  3.702158
# 7  10.091328  8.867609  3.749185  3.705466
# 8  10.284881  8.599272  3.687343  3.669792
# 9  15.384095  7.772284  3.507221  3.492597

# %%
pd.DataFrame(t_session, index=subjects, columns=distances).mean(axis=0)
# Out:
# les      11.432548
# lew       8.504614
# spdsw     3.683892
# logsw     3.665415
# dtype: float64

# %%
pd.DataFrame(t_session, index=subjects, columns=distances).std(axis=0)
# Out:
# les      2.232044
# lew      0.439430
# spdsw    0.101849
# logsw    0.101536
# dtype: float64

# %% [markdown]
# ### Cross Subjects

# %%
results_subject = pd.read_csv("./da_particles_cross_subject.csv")

# %%
results_subject
# Out:
#      Unnamed: 0     align  no_align       time distance  n_proj  n_epochs  \
# 0             0  1.000000  1.000000   0.000000      les     500       500
# 1             1  0.759259  0.522222  14.217470      les     500       500
# 2             2  0.594096  0.505535  11.290337      les     500       500
# 3             3  0.700758  0.390152   9.099653      les     500       500
# 4             4  0.468354  0.265823  10.021838      les     500       500
# ..          ...       ...       ...        ...      ...     ...       ...
# 495         495  0.542125  0.267399   3.511295    logsw     500       500
# 496         496  0.562963  0.285185   3.522498    logsw     500       500
# 497         497  0.487085  0.247232   3.499616    logsw     500       500
# 498         498  0.587121  0.397727   3.511898    logsw     500       500
# 499         499  1.000000  1.000000   0.000000    logsw     500       500
#
#      seed  subject  target_subject  multifreq   reg  cross_subject
# 0    2473        1               1      False  10.0           True
# 1    2473        1               3      False  10.0           True
# 2    2473        1               7      False  10.0           True
# 3    2473        1               8      False  10.0           True
# 4    2473        1               9      False  10.0           True
# ..    ...      ...             ...        ...   ...            ...
# 495   929        9               1      False   1.0           True
# 496   929        9               3      False   1.0           True
# 497   929        9               7      False   1.0           True
# 498   929        9               8      False   1.0           True
# 499   929        9               9      False   1.0           True
#
# [500 rows x 13 columns]

# %%
distances = results_subject["distance"].unique()
subjects_src = results_subject["subject"].unique()
subjects_tgt = results_subject["target_subject"].unique()

# %%
n_epochs = 500 # 250

L_subject = {}
for distance in distances:
    L_subject[distance] = {}
L_subject["no_align"] = {}


for distance in distances:
    for s1 in subjects_src:
        L_subject[distance][s1] = {}
        for s2 in subjects_tgt:
            if s1 != s2:
                L_subject[distance][s1][s2] = {}
        
                scores = results_subject[
                    (results_subject["distance"] == distance)
                    & (results_subject["subject"] == s1)
                    & (results_subject["target_subject"] == s2)
                    & (results_subject["n_epochs"] == n_epochs) 
                ]["align"]
                m_score = scores.mean()
                std_score = scores.std()
                
                times = results_subject[
                    (results_subject["distance"] == distance)
                    & (results_subject["subject"] == s1)
                    & (results_subject["target_subject"] == s2)
                    & (results_subject["n_epochs"] == n_epochs)
                ]["time"]
                
                m_t = times.mean()
                std_t = times.std()
                
                L_subject[distance][s1][s2]["mean_score"] = m_score
                L_subject[distance][s1][s2]["std_score"] = std_score
                L_subject[distance][s1][s2]["mean_time"] = m_t
                L_subject[distance][s1][s2]["std_t"] = std_t
        
        
for s1 in subjects_src:
    L_subject["no_align"][s1] = {}
    for s2 in subjects_tgt:
        if s1 != s2:
            dico_distances = {"mean_score": 0, "std_score": 0, "mean_time": 0, "std_time":0}

            scores = results_subject[
                (results_subject["distance"] == distance)
                & (results_subject["subject"] == s1)
                & (results_subject["target_subject"] == s2)
                & (results_subject["n_epochs"] == n_epochs)
            ]["no_align"]
            m_score = scores.mean()
            std_score = scores.std()

            dico_distances["mean_score"] = m_score
            dico_distances["std_score"] = std_score

            L_subject["no_align"][s1][s2] = dico_distances

# %%
L_subject
# Out:
# {'les': {1: {3: {'mean_score': 0.7407407407407407,
#     'std_score': 0.023715274953455028,
#     'mean_time': 10.978870820999145,
#     'std_t': 1.8133326289024276},
#    7: {'mean_score': 0.592619926199262,
#     'std_score': 0.010630893203607323,
#     'mean_time': 10.516930389404298,
#     'std_t': 0.44018801096656857},
#    8: {'mean_score': 0.7106060606060607,
#     'std_score': 0.006338333534349052,
#     'mean_time': 10.111451578140258,
#     'std_t': 0.6547410747964453},
#    9: {'mean_score': 0.48607594936708864,
#     'std_score': 0.01132186317721416,
#     'mean_time': 10.094027090072633,
#     'std_t': 0.3562804938694495}},
#   3: {1: {'mean_score': 0.6542124542124542,
#     'std_score': 0.021137784683155338,
#     'mean_time': 10.723714208602905,
#     'std_t': 0.4762621468283339},
#    7: {'mean_score': 0.6568265682656828,
#     'std_score': 0.006391331393243099,
#     'mean_time': 10.266517925262452,
#     'std_t': 0.500621000884828},
#    8: {'mean_score': 0.6803030303030303,
#     'std_score': 0.014816369102733321,
#     'mean_time': 10.267534589767456,
#     'std_t': 0.3378748353576874},
#    9: {'mean_score': 0.540084388185654,
#     'std_score': 0.011555328217408548,
#     'mean_time': 10.260361671447754,
#     'std_t': 0.35810264076234766}},
#   7: {1: {'mean_score': 0.5860805860805861,
#     'std_score': 0.00366300366300365,
#     'mean_time': 10.341062545776367,
#     'std_t': 0.3485465923285451},
#    3: {'mean_score': 0.6844444444444445,
#     'std_score': 0.019137793604094507,
#     'mean_time': 10.197298812866212,
#     'std_t': 0.2897174283009017},
#    8: {'mean_score': 0.587878787878788,
#     'std_score': 0.006775963568181175,
#     'mean_time': 10.363595533370972,
#     'std_t': 0.4799061825926166},
#    9: {'mean_score': 0.5223628691983123,
#     'std_score': 0.006933196930445151,
#     'mean_time': 10.250630855560303,
#     'std_t': 0.3289653495836905}},
#   8: {1: {'mean_score': 0.6227106227106227,
#     'std_score': 0.027041800476617927,
#     'mean_time': 10.629637479782104,
#     'std_t': 0.5405911313272405},
#    3: {'mean_score': 0.6866666666666666,
#     'std_score': 0.01844429570072405,
#     'mean_time': 10.449585390090942,
#     'std_t': 0.43680349916916605},
#    7: {'mean_score': 0.6103321033210332,
#     'std_score': 0.01395400029608048,
#     'mean_time': 10.427536964416504,
#     'std_t': 0.6189370041786693},
#    9: {'mean_score': 0.5510548523206751,
#     'std_score': 0.009713809648288054,
#     'mean_time': 10.401540565490723,
#     'std_t': 0.32833571103763076}},
#   9: {1: {'mean_score': 0.5956043956043956,
#     'std_score': 0.008432867716645639,
#     'mean_time': 10.012355089187622,
#     'std_t': 0.3803628614231266},
#    3: {'mean_score': 0.7148148148148148,
#     'std_score': 0.00979907892986889,
#     'mean_time': 10.381257915496827,
#     'std_t': 0.5449071848108238},
#    7: {'mean_score': 0.5653136531365314,
#     'std_score': 0.0070979276980336825,
#     'mean_time': 9.636918020248412,
#     'std_t': 0.6218209646876859},
#    8: {'mean_score': 0.7204545454545455,
#     'std_score': 0.014273820970770268,
#     'mean_time': 10.182433605194092,
#     'std_t': 0.44904895446911697}}},
#  'lew': {1: {3: {'mean_score': 0.725925925925926,
#     'std_score': 0.0,
#     'mean_time': 8.944469499588013,
#     'std_t': 0.03303692578946959},
#    7: {'mean_score': 0.5542435424354244,
#     'std_score': 0.0016502346697415196,
#     'mean_time': 8.3966543674469,
#     'std_t': 0.029217111380302953},
#    8: {'mean_score': 0.6931818181818182,
#     'std_score': 0.0,
#     'mean_time': 9.048523139953613,
#     'std_t': 0.05431105737455144},
#    9: {'mean_score': 0.540084388185654,
#     'std_score': 0.0,
#     'mean_time': 8.958198070526125,
#     'std_t': 0.07032337003181749}},
#   3: {1: {'mean_score': 0.6336996336996337,
#     'std_score': 0.0,
#     'mean_time': 8.898700141906739,
#     'std_t': 0.027068275950520127},
#    7: {'mean_score': 0.6199261992619927,
#     'std_score': 0.0,
#     'mean_time': 17.543571376800536,
#     'std_t': 0.08518147620175555},
#    8: {'mean_score': 0.6212121212121212,
#     'std_score': 0.0,
#     'mean_time': 8.769607973098754,
#     'std_t': 0.03144979973629439},
#    9: {'mean_score': 0.5358649789029536,
#     'std_score': 0.0,
#     'mean_time': 8.866363143920898,
#     'std_t': 0.056026023085180426}},
#   7: {1: {'mean_score': 0.5018315018315018,
#     'std_score': 0.0,
#     'mean_time': 14.402113056182861,
#     'std_t': 0.04184465693030882},
#    3: {'mean_score': 0.6296296296296297,
#     'std_score': 0.0,
#     'mean_time': 7.867949533462524,
#     'std_t': 0.05137173612413816},
#    8: {'mean_score': 0.4810606060606061,
#     'std_score': 0.0,
#     'mean_time': 9.14222297668457,
#     'std_t': 0.04843951505815849},
#    9: {'mean_score': 0.5147679324894515,
#     'std_score': 0.0,
#     'mean_time': 8.92217583656311,
#     'std_t': 0.04784708482607964}},
#   8: {1: {'mean_score': 0.6153846153846154,
#     'std_score': 0.0,
#     'mean_time': 9.209073495864867,
#     'std_t': 0.05352314788420422},
#    3: {'mean_score': 0.7407407407407407,
#     'std_score': 0.0,
#     'mean_time': 8.91168794631958,
#     'std_t': 0.027862382710793332},
#    7: {'mean_score': 0.5387453874538746,
#     'std_score': 0.0,
#     'mean_time': 9.354728317260742,
#     'std_t': 0.05272381870756848},
#    9: {'mean_score': 0.5721518987341773,
#     'std_score': 0.003773954392404712,
#     'mean_time': 8.132057189941406,
#     'std_t': 0.05614069093321889}},
#   9: {1: {'mean_score': 0.48351648351648346,
#     'std_score': 6.206335383118183e-17,
#     'mean_time': 9.200142049789429,
#     'std_t': 0.043499116685957476},
#    3: {'mean_score': 0.6333333333333333,
#     'std_score': 0.0,
#     'mean_time': 8.952633714675903,
#     'std_t': 0.04840069174428594},
#    7: {'mean_score': 0.5719557195571956,
#     'std_score': 0.0,
#     'mean_time': 9.050317668914795,
#     'std_t': 0.05360101876126188},
#    8: {'mean_score': 0.6401515151515151,
#     'std_score': 0.0,
#     'mean_time': 8.267988157272338,
#     'std_t': 0.02622675692195322}}},
#  'spdsw': {1: {3: {'mean_score': 0.6903703703703703,
#     'std_score': 0.01188652335991201,
#     'mean_time': 3.741845703125,
#     'std_t': 0.012813087741857052},
#    7: {'mean_score': 0.6088560885608856,
#     'std_score': 0.014989000746560862,
#     'mean_time': 3.7455050468444826,
#     'std_t': 0.009097573185023898},
#    8: {'mean_score': 0.6818181818181818,
#     'std_score': 0.011978324470334803,
#     'mean_time': 3.7411776065826414,
#     'std_t': 0.012987962756007242},
#    9: {'mean_score': 0.5215189873417722,
#     'std_score': 0.017549902399228188,
#     'mean_time': 3.643731117248535,
#     'std_t': 0.02131744428605149}},
#   3: {1: {'mean_score': 0.6622710622710622,
#     'std_score': 0.034401045807689094,
#     'mean_time': 3.731341314315796,
#     'std_t': 0.017165486133316185},
#    7: {'mean_score': 0.7018450184501845,
#     'std_score': 0.017189394389449626,
#     'mean_time': 3.7183634281158446,
#     'std_t': 0.008735679710766012},
#    8: {'mean_score': 0.7083333333333333,
#     'std_score': 0.020747066572165396,
#     'mean_time': 3.713048315048218,
#     'std_t': 0.017094430540595496},
#    9: {'mean_score': 0.5569620253164558,
#     'std_score': 0.006671471856895321,
#     'mean_time': 3.6211116790771483,
#     'std_t': 0.009083213711287438}},
#   7: {1: {'mean_score': 0.5802197802197802,
#     'std_score': 0.017297756707864605,
#     'mean_time': 3.7593288898468016,
#     'std_t': 0.015119653550933346},
#    3: {'mean_score': 0.7103703703703703,
#     'std_score': 0.011535119631405535,
#     'mean_time': 3.743648719787598,
#     'std_t': 0.012000456773898155},
#    8: {'mean_score': 0.6181818181818182,
#     'std_score': 0.01863389981249823,
#     'mean_time': 3.7361106395721437,
#     'std_t': 0.012271282860116335},
#    9: {'mean_score': 0.5299578059071729,
#     'std_score': 0.0128674689299383,
#     'mean_time': 3.6416680812835693,
#     'std_t': 0.008302990313423573}},
#   8: {1: {'mean_score': 0.5772893772893773,
#     'std_score': 0.02736241669887636,
#     'mean_time': 3.699228572845459,
#     'std_t': 0.008611558194383879},
#    3: {'mean_score': 0.7044444444444444,
#     'std_score': 0.02490035009477276,
#     'mean_time': 3.7083038806915285,
#     'std_t': 0.013302099869044355},
#    7: {'mean_score': 0.581549815498155,
#     'std_score': 0.004950704009224651,
#     'mean_time': 3.704736852645874,
#     'std_t': 0.008916035364610034},
#    9: {'mean_score': 0.5746835443037975,
#     'std_score': 0.025033581391040245,
#     'mean_time': 3.6015949726104735,
#     'std_t': 0.017645552306288784}},
#   9: {1: {'mean_score': 0.5523809523809524,
#     'std_score': 0.013558062654448168,
#     'mean_time': 3.5560963630676268,
#     'std_t': 0.020009319740597647},
#    3: {'mean_score': 0.6185185185185185,
#     'std_score': 0.027216552697590896,
#     'mean_time': 3.5330409526824953,
#     'std_t': 0.014656703968739148},
#    7: {'mean_score': 0.5210332103321033,
#     'std_score': 0.025351386032941202,
#     'mean_time': 3.5452144622802733,
#     'std_t': 0.020562957184384303},
#    8: {'mean_score': 0.6568181818181819,
#     'std_score': 0.029656938077368765,
#     'mean_time': 3.5211923122406006,
#     'std_t': 0.02043673436160995}}},
#  'logsw': {1: {3: {'mean_score': 0.697037037037037,
#     'std_score': 0.01913779360409453,
#     'mean_time': 3.721813106536865,
#     'std_t': 0.010523337535208134},
#    7: {'mean_score': 0.6140221402214021,
#     'std_score': 0.017030229902899402,
#     'mean_time': 3.7261117935180663,
#     'std_t': 0.01179816566114238},
#    8: {'mean_score': 0.6757575757575757,
#     'std_score': 0.012156671618091816,
#     'mean_time': 3.7228638172149657,
#     'std_t': 0.009271042981772682},
#    9: {'mean_score': 0.4894514767932489,
#     'std_score': 0.019790783796723305,
#     'mean_time': 3.6141345500946045,
#     'std_t': 0.016927169004252545}},
#   3: {1: {'mean_score': 0.6754578754578755,
#     'std_score': 0.016092221711713414,
#     'mean_time': 3.7178252220153807,
#     'std_t': 0.016611167746958002},
#    7: {'mean_score': 0.6597785977859779,
#     'std_score': 0.033557025961297865,
#     'mean_time': 3.677847385406494,
#     'std_t': 0.001918467693274803},
#    8: {'mean_score': 0.7121212121212122,
#     'std_score': 0.02425425847512444,
#     'mean_time': 3.689956045150757,
#     'std_t': 0.013369911190423344},
#    9: {'mean_score': 0.5510548523206752,
#     'std_score': 0.013541608891039015,
#     'mean_time': 3.6131379127502443,
#     'std_t': 0.018976719941432362}},
#   7: {1: {'mean_score': 0.5677655677655677,
#     'std_score': 0.010031548672255764,
#     'mean_time': 3.7147987365722654,
#     'std_t': 0.01056610758523387},
#    3: {'mean_score': 0.6748148148148148,
#     'std_score': 0.014907119849998608,
#     'mean_time': 3.7197001934051515,
#     'std_t': 0.013990715716048922},
#    8: {'mean_score': 0.5931818181818181,
#     'std_score': 0.018284118766889637,
#     'mean_time': 3.7060215950012205,
#     'std_t': 0.014470780255557066},
#    9: {'mean_score': 0.5037974683544304,
#     'std_score': 0.008225142907011792,
#     'mean_time': 3.6061122894287108,
#     'std_t': 0.01572577442859338}},
#   8: {1: {'mean_score': 0.6102564102564103,
#     'std_score': 0.018056787610060413,
#     'mean_time': 3.680838632583618,
#     'std_t': 0.013951590207896224},
#    3: {'mean_score': 0.6970370370370371,
#     'std_score': 0.02637182684284133,
#     'mean_time': 3.6913251876831055,
#     'std_t': 0.00884114044959801},
#    7: {'mean_score': 0.5468634686346864,
#     'std_score': 0.021421291916900356,
#     'mean_time': 3.663414478302002,
#     'std_t': 0.009453731855462288},
#    9: {'mean_score': 0.5459915611814345,
#     'std_score': 0.029475526070165344,
#     'mean_time': 3.57053599357605,
#     'std_t': 0.01822302978018901}},
#   9: {1: {'mean_score': 0.5421245421245421,
#     'std_score': 0.021201166488626712,
#     'mean_time': 3.5151743412017824,
#     'std_t': 0.01313076822827899},
#    3: {'mean_score': 0.6,
#     'std_score': 0.037405573845785474,
#     'mean_time': 3.516697359085083,
#     'std_t': 0.005110141964686874},
#    7: {'mean_score': 0.47232472324723246,
#     'std_score': 0.036248861078207566,
#     'mean_time': 3.5169368267059324,
#     'std_t': 0.011163607088262532},
#    8: {'mean_score': 0.5818181818181818,
#     'std_score': 0.05086205890261102,
#     'mean_time': 3.505888652801514,
#     'std_t': 0.012385529690341696}}},
#  'no_align': {1: {3: {'mean_score': 0.5222222222222223,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    7: {'mean_score': 0.5055350553505535,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    8: {'mean_score': 0.3901515151515152,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    9: {'mean_score': 0.26582278481012656,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0}},
#   3: {1: {'mean_score': 0.3443223443223443,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    7: {'mean_score': 0.30996309963099633,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    8: {'mean_score': 0.4962121212121212,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    9: {'mean_score': 0.2742616033755274,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0}},
#   7: {1: {'mean_score': 0.5201465201465202,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    3: {'mean_score': 0.5333333333333333,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    8: {'mean_score': 0.26136363636363635,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    9: {'mean_score': 0.26582278481012656,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0}},
#   8: {1: {'mean_score': 0.4981684981684982,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    3: {'mean_score': 0.5777777777777777,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    7: {'mean_score': 0.24354243542435422,
#     'std_score': 3.1031676915590914e-17,
#     'mean_time': 0,
#     'std_time': 0},
#    9: {'mean_score': 0.3966244725738397,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0}},
#   9: {1: {'mean_score': 0.2673992673992674,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    3: {'mean_score': 0.2851851851851852,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    7: {'mean_score': 0.2472324723247233,
#     'std_score': 0.0,
#     'mean_time': 0,
#     'std_time': 0},
#    8: {'mean_score': 0.39545454545454545,
#     'std_score': 0.005081972676135856,
#     'mean_time': 0,
#     'std_time': 0}}}}

# %%
results_mean = np.zeros((len(subjects_src), len(distances)+1))
t_subjects = np.zeros((len(subjects_src), len(distances)))

for l, distance in enumerate(L_subject):
    results = np.zeros((5,5))
    ts = np.zeros((5,5))
    for i, s1 in enumerate(subjects_src):
        for j, s2 in enumerate(subjects_tgt):
            if s1 != s2:
                results[i, j] = L_subject[distance][s1][s2]["mean_score"]
                if distance != "no_align":
                    ts[i, j] = L_subject[distance][s1][s2]["mean_time"]
                
        results_mean[i, l] = np.sum(results[i, :])/4
        
        if distance != "no_align":
            t_subjects[i, l] = np.sum(ts[i, :])/4
                       
    results_pd = pd.DataFrame(results, index=subjects_src, columns=subjects_tgt)
    print(distance)
    print(results_pd)
    print()
# Out:
# les
#           1         3         7         8         9
# 1  0.000000  0.740741  0.592620  0.710606  0.486076
# 3  0.654212  0.000000  0.656827  0.680303  0.540084
# 7  0.586081  0.684444  0.000000  0.587879  0.522363
# 8  0.622711  0.686667  0.610332  0.000000  0.551055
# 9  0.595604  0.714815  0.565314  0.720455  0.000000
#
# lew
#           1         3         7         8         9
# 1  0.000000  0.725926  0.554244  0.693182  0.540084
# 3  0.633700  0.000000  0.619926  0.621212  0.535865
# 7  0.501832  0.629630  0.000000  0.481061  0.514768
# 8  0.615385  0.740741  0.538745  0.000000  0.572152
# 9  0.483516  0.633333  0.571956  0.640152  0.000000
#
# spdsw
#           1         3         7         8         9
# 1  0.000000  0.690370  0.608856  0.681818  0.521519
# 3  0.662271  0.000000  0.701845  0.708333  0.556962
# 7  0.580220  0.710370  0.000000  0.618182  0.529958
# 8  0.577289  0.704444  0.581550  0.000000  0.574684
# 9  0.552381  0.618519  0.521033  0.656818  0.000000
#
# logsw
#           1         3         7         8         9
# 1  0.000000  0.697037  0.614022  0.675758  0.489451
# 3  0.675458  0.000000  0.659779  0.712121  0.551055
# 7  0.567766  0.674815  0.000000  0.593182  0.503797
# 8  0.610256  0.697037  0.546863  0.000000  0.545992
# 9  0.542125  0.600000  0.472325  0.581818  0.000000
#
# no_align
#           1         3         7         8         9
# 1  0.000000  0.522222  0.505535  0.390152  0.265823
# 3  0.344322  0.000000  0.309963  0.496212  0.274262
# 7  0.520147  0.533333  0.000000  0.261364  0.265823
# 8  0.498168  0.577778  0.243542  0.000000  0.396624
# 9  0.267399  0.285185  0.247232  0.395455  0.000000

# %%
print("Mean Accuracy Cross Subject + Particles")
pd.DataFrame(results_mean, index=subjects_src, columns=np.concatenate([distances, ["no_align"]]))
# Out:
# Mean Accuracy Cross Subject + Particles
#         les       lew     spdsw     logsw  no_align
# 1  0.632511  0.628359  0.625641  0.619067  0.420933
# 3  0.632857  0.602676  0.657353  0.649603  0.356190
# 7  0.595192  0.531822  0.609682  0.584890  0.395167
# 8  0.617691  0.616756  0.609492  0.600037  0.429028
# 9  0.649047  0.582239  0.587188  0.549067  0.298818

# %%
pd.DataFrame(results_mean, index=subjects_src, columns=np.concatenate([distances, ["no_align"]])).mean(axis=0)
# Out:
# les         0.625459
# lew         0.592370
# spdsw       0.617871
# logsw       0.600533
# no_align    0.380027
# dtype: float64

# %%
pd.DataFrame(results_mean, index=subjects_src, columns=np.concatenate([distances, ["no_align"]])).std(axis=0)
# Out:
# les         0.020232
# lew         0.037963
# spdsw       0.025971
# logsw       0.037567
# no_align    0.053541
# dtype: float64

# %%
print("Runtime Cross Subject + Particles")
pd.DataFrame(t_subjects, index=subjects_src, columns=distances)
# Out:
# Runtime Cross Subject + Particles
#          les        lew     spdsw     logsw
# 1  10.425320   8.836961  3.718065  3.696231
# 3  10.379532  11.019561  3.695966  3.674692
# 7  10.288147  10.083615  3.720189  3.686658
# 8  10.477075   8.901887  3.678466  3.651529
# 9  10.053241   8.867770  3.538886  3.513674

# %%
pd.DataFrame(t_subjects, index=subjects_src, columns=distances).mean(axis=0)
# Out:
# les      10.324663
# lew       9.541959
# spdsw     3.670314
# logsw     3.644557
# dtype: float64

# %%
pd.DataFrame(t_subjects, index=subjects_src, columns=distances).std(axis=0)
# Out:
# les      0.166865
# lew      0.979533
# spdsw    0.075441
# logsw    0.075049
# dtype: float64
